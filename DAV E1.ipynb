# %%
# Importing library (One Way ANOVA)
from scipy.stats import f_oneway
# Importing libraries (Two Way ANOVA)
import statsmodels
import statsmodels.api
from statsmodels.stats.anova import anova_lm
from statsmodels.formula.api import ols
import numpy as np
import pandas as pd

# %%
# one way ANOVA
perf1 = [9,10,12,13]
perf2 = [4,5,7,8]
perf3 = [16,14,20,8]
perf4 = [18,20,22,27]

# %%
f_oneway(perf1,perf2,perf3,perf4)
# Out:
# F_onewayResult(statistic=15.046511627906975, pvalue=0.00022781028478125278)

# %%
file_path_1 = '/content/drive/MyDrive/DAV Experiments/anova.xlsx'
file_path_2 = '/content/drive/MyDrive/DAV Experiments/anova2.csv'
df = pd.read_excel(file_path_1)
df3 = pd.read_csv(file_path_2)

# %%
df
# Out:
#    PlotLand  A  B  C
# 0         1  6  5  5
# 1         2  7  5  4
# 2         3  3  3  3
# 3         4  8  7  4

# %%
df2 = df.drop(['PlotLand'], axis = 1)

# %%
formula = 'SeedProductivity ~ C(SeedVariety)+C(FertilizerVariety)'

# %%
df3
# Out:
#     SeedProductivity SeedVariety FertilizerVariety
# 0                  6           A                 W
# 1                  7           A                 X
# 2                  3           A                 Y
# 3                  8           A                 Z
# 4                  5           B                 W
# 5                  5           B                 X
# 6                  3           B                 Y
# 7                  7           B                 Z
# 8                  5           C                 W
# 9                  4           C                 X
# 10                 3           C                 Y
# 11                 4           C                 Z

# %%
model = statsmodels.formula.api.ols(formula,data = df3).fit()
aov_table = anova_lm(model, type=2)

# %%
print(aov_table)
# Out:
#                        df  sum_sq  mean_sq    F    PR(>F)
# C(SeedVariety)        2.0     8.0      4.0  4.0  0.078717
# C(FertilizerVariety)  3.0    18.0      6.0  6.0  0.030796
# Residual              6.0     6.0      1.0  NaN       NaN
